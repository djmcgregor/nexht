# %%
import cv2
import matplotlib.pyplot as plt

# %%
# Appears nighttime video = 10 fps
#         daytime video = 20 fps

# %%
# def get_video(path):
def initialize_video(files):
    for video in files:
        cap = cv2.VideoCapture(video)
        fps = cv2.VideoCapture.get(cap, cv2.CAP_PROP_FPS)
        width = int(cv2.VideoCapture.get(cap, cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cv2.VideoCapture.get(cap, cv2.CAP_PROP_FRAME_HEIGHT))

        fourcc = cv2.VideoWriter_fourcc(*'XVID')
        out = cv2.VideoWriter('output.mp4', fourcc, 2*fps, (height, width))

# %%
print(fps, height, width)
# Out:
# 10.0 1080 1920

# %%
cap = cv2.VideoCapture('01.h264')
fps = cv2.VideoCapture.get(cap, cv2.CAP_PROP_FPS)
width = int(cv2.VideoCapture.get(cap, cv2.CAP_PROP_FRAME_WIDTH))
height = int(cv2.VideoCapture.get(cap, cv2.CAP_PROP_FRAME_HEIGHT))

fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('output.mp4', fourcc, 2*fps, (height, width))

# %%
if (cap.isOpened() == False):
    print("Error opening video file")

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret == True:
        
        rot_frame = cv2.rotate(frame, cv2.ROTATE_90_COUNTERCLOCKWISE)

        out.write(rot_frame)
        
        # cv2.imshow('Frame', frame)
        # if cv2.waitKey(25) & 0xFF == ord('q'):
        #     break
    else:
        break
cap.release()
out.release()
cv2.destroyAllWindows()

# %%
img = cv2.imread('output_Moment.jpg')
plt.imshow(img)
plt.show()

# %%
center = (width/2, height/2)
M = cv2.getRotationMatrix2D(center, 90, 1.0)
rot90 = cv2.warpAffine(img, M, (height, width))

# %%
rot90 = cv2.rotate(img, cv2.ROTATE_90_COUNTERCLOCKWISE)
cv2.putText(rot90, '2020.06.08 15:02:06', (10, 40), cv2.FONT_HERSHEY_SIMPLEX, 1.5, (209, 80, 0, 255), 5)
# plt.imshow(rot90)

cv2.imwrite('test.jpg', rot90)
# Out:
# True
